# %% [markdown]
# #THEORY QUESTIONS

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#
# Interpreted languages execute code line by line (e.g., Python), while compiled languages are transformed into machine code before execution (e.g., C/C++), resulting in faster execution.
#
#
#
# 2. What is exception handling in Python?
#
# Exception handling allows the program to deal with runtime errors using try, except, else, and finally blocks to prevent crashes and manage error recovery.
#
#
#
# 3. What is the purpose of the finally block in exception handling?
#
# The finally block is used to execute code regardless of whether an exception occurred or not, typically for cleanup operations.
#
#
#
# 4. What is logging in Python?
#
# Logging is the process of recording events or messages during program execution, often for debugging or monitoring purposes, using Python’s logging module.
#
#
#
# 5. What is the significance of the _del_ method in Python?
#
# The _del_ method is a destructor called when an object is about to be destroyed. It is used to define cleanup actions before the object is removed from memory.
#
#
#
# 6. What is the difference between import and from ... import in Python?
#
# import module imports the whole module. from module import function imports specific attributes or functions directly.
#
#
#
# 7. How can you handle multiple exceptions in Python?
#
# Use multiple except blocks or combine exceptions in a tuple:
#
# try:
#     # code
# except (TypeError, ValueError) as e:
#     # handle both
#
#
#
# 8. What is the purpose of the with statement when handling files in Python?
#
# The with statement ensures that a file is properly closed after its suite finishes, even if an exception is raised.
#
#
#
# 9. What is the difference between multithreading and multiprocessing?
#
# Multithreading runs threads in the same memory space; multiprocessing runs processes in separate memory spaces. Multiprocessing is better for CPU-bound tasks.
#
#
#
# 10. What are the advantages of using logging in a program?
#
# Helps in debugging, monitoring application behavior, saving history of execution, and identifying issues after deployment.
#
#
#
# 11. What is memory management in Python?
#
# It refers to how Python handles memory allocation and deallocation automatically using reference counting and garbage collection.
#
#
#
# 12. What are the basic steps involved in exception handling in Python?
#
# Use try to enclose code, except to catch exceptions, optionally else to run if no exception, and finally for cleanup.
#
#
#
# 13. Why is memory management important in Python?
#
# To optimize resource usage, improve performance, and prevent memory leaks or crashes due to exhausted memory.
#
#
#
# 14. What is the role of try and except in exception handling?
#
# try defines a block where exceptions might occur. except catches and handles those exceptions gracefully.
#
#
#
# 15. How does Python's garbage collection system work?
#
# Python uses reference counting and a cyclic garbage collector to detect and reclaim memory occupied by unused objects.
#
#
#
# 16. What is the purpose of the else block in exception handling?
#
# The else block runs if no exceptions are raised in the try block, useful for code that should run only if the try was successful.
#
#
#
# 17. What are the common logging levels in Python?
#
# DEBUG, INFO, WARNING, ERROR, and CRITICAL.
#
#
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
# os.fork() creates a child process in Unix systems by duplicating the parent, while multiprocessing is a cross-platform module to create processes.
#
#
#
# 19. What is the importance of closing a file in Python?
#
# It releases system resources and ensures data is properly written to disk. Using with handles this automatically.
#
#
#
# 20. What is the difference between file.read() and file.readline() in Python?
#
# file.read() reads the entire file or specified number of bytes. file.readline() reads a single line from the file.
#
#
#
# 21. What is the logging module in Python used for?
#
# It is used to track events that happen when the software runs, allowing developers to log messages with different severity levels.
#
#
#
# 22. What is the os module in Python used for in file handling?
#
# The os module allows interaction with the operating system, such as navigating directories, deleting files, or creating paths.
#
#
#
# 23. What are the challenges associated with memory management in Python?
#
# Dealing with circular references, memory leaks in long-running programs, and understanding object lifecycle.
#
#
#
# 24. How do you raise an exception manually in Python?
#
# Use the raise keyword:
#
# raise ValueError("An error occurred")
#
#
#
# 25. Why is it important to use multithreading in certain applications?
#
# For better responsiveness in I/O-bound applications like GUI apps, or to perform background tasks without blocking the main thread.

# %% [markdown]
# # PRECTICAL QUESTIONS

# %%
# 1. How can you open a file for writing in python and write a string to it.

with open("output.txt", "w") as file:
    file.write("Hello, world!")

# %%
# 2. Write a python program to read the contents of a file and print each line.

with open("output.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, world!

# %%
# 3. How would you handle a case where the file doesnot exist while trying to open it for reading.

try:
    with open("nonexistent.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    print("File does not exist.")
# Out:
# File does not exist.

# %%
# 4. Write a pyhton script that reads from one file and writes its contant to another file.


# File Copy Script

# Specify the source and destination file paths
source_file = 'source.txt'
destination_file = 'destination.txt'

try:
    # Open the source file in read mode
    with open(source_file, 'r') as src:
        content = src.read()

    # Open the destination file in write mode and write the content
    with open(destination_file, 'w') as dest:
        dest.write(content)

    print("File content copied successfully.")

except FileNotFoundError:
    print(f"Error: The file '{source_file}' was not found.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Error: The file 'source.txt' was not found.

# %%
# 5. How would you catch and handle division by zero error in python.

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Division by zero is not allowed.")
# Out:
# Division by zero is not allowed.

# %%
# 6. Write a pyhton program that logs an error message to a log file when a division by zero exception occurs.

import logging

logging.basicConfig(filename='error.log', level=logging.ERROR)

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error("Division by zero error: %s", e)
# Out:
# ERROR:root:Division by zero error: division by zero

# %%
# 7. How do you log information at different levels (INFO,ERROR,WARNING) in python using the loging module.

import logging

logging.basicConfig(level=logging.DEBUG, filename="logfile.log", filemode="a",
                    format="%(asctime)s - %(levelname)s - %(message)s")

logging.info("This is an informational message.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.

# %%
# 8. Write a program to handle a file opening error using exception handling.

try:
    with open("file.txt", "r") as file:
        data = file.read()
except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %%
# 10. How can you append data to an existing file in pyhton.


with open("file.txt", "a") as file:
    file.write("Appending this line.\n")

# %%
# 11. Write a python program that uses a try-except block to handle an error when attempting to access a dictonary key that doesnot exist.

data = {"name": "John"}

try:
    print(data["age"])
except KeyError:
    print("Key does not exist.")
# Out:
# Key does not exist.

# %%
# 12. Write a program that demonstrates using multiple accept blocks to handle different types of acceptions.

try:
    value = int(input("Enter a number: "))
except ValueError:
    print("Invalid input. Please enter a valid number.")
except KeyboardInterrupt:
    print("\nOperation cancelled.")
# Out:
# Enter a number: jkk
# Invalid input. Please enter a valid number.

# %%
# 13. How would you check if a file exists before attempting to read it in python.


import os

if os.path.exists("file.txt"):
    with open("file.txt", "r") as file:
        print(file.read())
else:
    print("File does not exist.")
# Out:
# Appending this line.
# Appending this line.

# %%
# 14. Write a program that uses the loging module to both informational and error messages.

import logging

logging.basicConfig(filename='app.log', level=logging.INFO)

try:
    x = 10 / 0
except ZeroDivisionError:
    logging.error("Tried to divide by zero.")

logging.info("Program completed.")
# Out:
# ERROR:root:Tried to divide by zero.

# %%
# 15. write a python program that prints the contant of a file and handles the case when the file is empty.


filename = "user_data.txt"

# Writing user input
with open(filename, "w") as file:
    data = input("Enter some data: ")
    file.write(data)

# Reading and checking if empty
with open(filename, "r") as file:
    content = file.read()
    if content == "":
        print("File is empty.")
    else:
        print("File has content.")
# Out:
# Enter some data: My name is Mumin Shameem
# File has content.

# %%
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.

# !pip install memory_profiler

from memory_profiler import profile

@profile
def my_func():
    a = [i for i in range(10000)]
    return a

my_func()
# Out:
# ...
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 847, in enable
#     sys.settrace(self.trace_memory_usage)
#
#
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 850, in disable
#     sys.settrace(self._original_trace_function)
# ...

# %%
# 17. Write a ptyhon program to create and write a list of numbers to file, one number per line.


numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(f"{number}\n")

# %%
# 18. How would you implement a basi loging setup that logs to a file with rotation after 1MB.

import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("rotated.log", maxBytes=1_000_000, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.INFO,
                    format="%(asctime)s - %(levelname)s - %(message)s")

logging.info("Starting the logging service.")

# %%
# 19. Writ a program that handles both index error and key error using a try-except block.

data = {"name": "Alice"}
lst = [1, 2, 3]

try:
    print(lst[5])
    print(data["age"])
except IndexError:
    print("Index out of range.")
except KeyError:
    print("Key not found.")
# Out:
# Index out of range.

# %%
# 20. How would you open a file and read its contants using a context manager in pyhton.

with open("file.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Appending this line.
# Appending this line.

# %%
# 21. Write a python program that reads a file and prints the number of occurrences of a specfic word.

word_to_count = "python"

with open("file.txt", "r") as file:
    content = file.read()
    count = content.lower().count(word_to_count.lower())

print(f"The word '{word_to_count}' appears {count} times.")
# Out:
# The word 'python' appears 0 times.

# %%
# 22. How can you check if a file is empty before attempting to read its contents.

import os

if os.path.getsize("file.txt") == 0:
    print("File is empty.")
else:
    with open("file.txt", "r") as file:
        print(file.read())
# Out:
# Appending this line.
# Appending this line.

# %%
# 23. Write a python program that writes to log file when an error occurs during file handling.

import logging

logging.basicConfig(filename="error_log.log", level=logging.ERROR)

try:
    with open("missing_file.txt", "r") as file:
        data = file.read()
except Exception as e:
    logging.error("An error occurred: %s", e)
# Out:
# ERROR:root:An error occurred: [Errno 2] No such file or directory: 'missing_file.txt'
